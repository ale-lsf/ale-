# %% [markdown]
# <a href="https://colab.research.google.com/github/ale-lsf/ale-/blob/main/dicionariocopia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dicionários em Python 🐍
#
# ## O que é um Dicionário?
#
# Um **dicionário (dictionary)** é uma estrutura de dados que armazena informações no formato **chave : valor**.
#
# Podemos imaginar um dicionário como uma ficha cadastral:
#
# | Chave  | Valor    |
# | ------ | -------- |
# | nome   | Ana      |
# | idade  | 20       |
# | cidade | Blumenau |
#
# Em Python, os dicionários são criados utilizando `{}`.
#
# ---
#
# # Características dos Dicionários
#
# ✔ Armazenam dados em pares **chave:valor**
#
# ✔ As chaves devem ser únicas
#
# ✔ Permitem diferentes tipos de dados
#
# ✔ São mutáveis (podem ser alterados)
#
# ✔ Mantêm a ordem de inserção (Python 3.7+)
#
# ---
#
# # Criando um Dicionário
#
# ```python
# aluno = {
#     "nome": "Ana",
#     "idade": 20,
#     "cidade": "Blumenau"
# }
#
# print(aluno)
# ```
#
# Saída:
#
# ```python
# {'nome': 'Ana', 'idade': 20, 'cidade': 'Blumenau'}
# ```
#
# ---
#
# # Acessando Valores
#
# Para acessar um valor, utilizamos a chave.
#
# ```python
# aluno = {
#     "nome": "Ana",
#     "idade": 20
# }
#
# print(aluno["nome"])
# ```
#
# Saída:
#
# ```python
# Ana
# ```
#
# ---
#
# # Adicionando Novos Elementos
#
# ```python
# aluno = {
#     "nome": "Ana",
#     "idade": 20
# }
#
# aluno["curso"] = "Desenvolvimento de Sistemas"
#
# print(aluno)
# ```
#
# Saída:
#
# ```python
# {
#  'nome': 'Ana',
#  'idade': 20,
#  'curso': 'Desenvolvimento de Sistemas'
# }
# ```
#
# ---
#
# # Alterando Valores
#
# ```python
# aluno = {
#     "nome": "Ana",
#     "idade": 20
# }
#
# aluno["idade"] = 21
#
# print(aluno)
# ```
#
# Saída:
#
# ```python
# {'nome': 'Ana', 'idade': 21}
# ```
#
# ---
#
# # Removendo Elementos
#
# ## Utilizando `del`
#
# ```python
# aluno = {
#     "nome": "Ana",
#     "idade": 20,
#     "cidade": "Blumenau"
# }
#
# del aluno["cidade"]
#
# print(aluno)
# ```
#
# Saída:
#
# ```python
# {'nome': 'Ana', 'idade': 20}
# ```
#
# ---
#
# ## Utilizando `pop()`
#
# ```python
# aluno = {
#     "nome": "Ana",
#     "idade": 20
# }
#
# idade = aluno.pop("idade")
#
# print(idade)
# print(aluno)
# ```
#
# Saída:
#
# ```python
# 20
# {'nome': 'Ana'}
# ```
#
# ---
#
# # Verificando se uma Chave Existe
#
# ```python
# aluno = {
#     "nome": "Ana",
#     "idade": 20
# }
#
# print("nome" in aluno)
# print("curso" in aluno)
# ```
#
# Saída:
#
# ```python
# True
# False
# ```
#
# ---
#
# # Percorrendo um Dicionário
#
# ## Apenas as Chaves
#
# ```python
# aluno = {
#     "nome": "Ana",
#     "idade": 20,
#     "cidade": "Blumenau"
# }
#
# for chave in aluno:
#     print(chave)
# ```
#
# Saída:
#
# ```python
# nome
# idade
# cidade
# ```
#
# ---
#
# ## Apenas os Valores
#
# ```python
# for valor in aluno.values():
#     print(valor)
# ```
#
# Saída:
#
# ```python
# Ana
# 20
# Blumenau
# ```
#
# ---
#
# ## Chaves e Valores
#
# ```python
# for chave, valor in aluno.items():
#     print(chave, "=", valor)
# ```
#
# Saída:
#
# ```python
# nome = Ana
# idade = 20
# cidade = Blumenau
# ```
#
# ---
#
# # Obtendo Todas as Chaves
#
# ```python
# aluno = {
#     "nome": "Ana",
#     "idade": 20
# }
#
# print(aluno.keys())
# ```
#
# Saída:
#
# ```python
# dict_keys(['nome', 'idade'])
# ```
#
# ---
#
# # Obtendo Todos os Valores
#
# ```python
# print(aluno.values())
# ```
#
# Saída:
#
# ```python
# dict_values(['Ana', 20])
# ```
#
# ---
#
# # Obtendo Chaves e Valores
#
# ```python
# print(aluno.items())
# ```
#
# Saída:
#
# ```python
# dict_items([('nome', 'Ana'), ('idade', 20)])
# ```
#
# ---
#
# # Método `get()`
#
# O método `get()` evita erros caso a chave não exista.
#
# ### Exemplo com erro
#
# ```python
# aluno = {
#     "nome": "Ana"
# }
#
# print(aluno["idade"])
# ```
#
# Saída:
#
# ```python
# KeyError
# ```
#
# ---
#
# ### Utilizando `get()`
#
# ```python
# aluno = {
#     "nome": "Ana"
# }
#
# print(aluno.get("idade"))
# ```
#
# Saída:
#
# ```python
# None
# ```
#
# ---
#
# ### Valor padrão
#
# ```python
# print(aluno.get("idade", "Não informado"))
# ```
#
# Saída:
#
# ```python
# Não informado
# ```
#
# ---
#
# # Exemplo Prático – Cadastro de Aluno
#
# ```python
# aluno = {
#     "nome": "Carlos",
#     "idade": 18,
#     "curso": "Python"
# }
#
# print("Nome:", aluno["nome"])
# print("Curso:", aluno["curso"])
# ```
#
# ---
#
# # Exemplo Prático – Cadastro Dinâmico
#
# ```python
# aluno = {}
#
# aluno["nome"] = input("Nome: ")
# aluno["idade"] = int(input("Idade: "))
# aluno["cidade"] = input("Cidade: ")
#
# print(aluno)
# ```
#
# ---
#
# # Dicionário com Lista
#
# ```python
# aluno = {
#     "nome": "Ana",
#     "notas": [8.5, 9.0, 7.5]
# }
#
# print(aluno["notas"])
# ```
#
# Saída:
#
# ```python
# [8.5, 9.0, 7.5]
# ```
#
# ---
#
# # Lista de Dicionários
#
# Muito utilizada em sistemas e bancos de dados.
#
# ```python
# alunos = [
#     {"nome": "Ana", "idade": 20},
#     {"nome": "Carlos", "idade": 21},
#     {"nome": "Maria", "idade": 19}
# ]
#
# for aluno in alunos:
#     print(aluno["nome"])
# ```
#
# Saída:
#
# ```python
# Ana
# Carlos
# Maria
# ```
#
# ---
#
# # Exemplo Prático – Agenda Telefônica
#
# ```python
# agenda = {
#     "Ana": "99999-1111",
#     "Carlos": "99999-2222",
#     "Maria": "99999-3333"
# }
#
# nome = input("Digite o nome: ")
#
# if nome in agenda:
#     print("Telefone:", agenda[nome])
# else:
#     print("Contato não encontrado.")
# ```
#
# ---
#
# # Exercícios
#
# ## Exercício 1
#
# Crie um dicionário contendo:
#
# * nome
# * idade
# * cidade
#
# Exiba todas as informações.
#
# ---
#
# ## Exercício 2
#
# Altere a idade do dicionário criado anteriormente.
#
# ---
#
# ## Exercício 3
#
# Adicione a chave `"profissão"` ao dicionário.
#
# ---
#
# ## Exercício 4
#
# Percorra o dicionário exibindo:
#
# ```python
# Chave: nome -> Valor: Ana
# ```
#
# ---
#
# ## Exercício 5
#
# Crie um sistema simples de cadastro de produtos:
#
# ```python
# produto = {
#     "nome": "Notebook",
#     "preco": 3500,
#     "estoque": 10
# }
# ```
#
# Exiba todas as informações.
#
# ---
#
# ## Exercício 6
#
# Crie uma agenda telefônica com pelo menos 5 contatos.
#
# Permita ao usuário pesquisar um nome.
#
# ---
#
# ## Exercício 7
#
# Crie uma lista contendo 3 alunos.
#
# Cada aluno deve possuir:
#
# ```python
# nome
# idade
# nota
# ```
#
# Exiba todos os dados usando um laço `for`.
#
# ---
#
# # Comparação: Lista x Dicionário
#
# | Lista               | Dicionário           |
# | ------------------- | -------------------- |
# | Acesso por índice   | Acesso por chave     |
# | `[0]`, `[1]`, `[2]` | `"nome"`, `"idade"`  |
# | Mantém sequência    | Organiza por chave   |
# | Ideal para coleções | Ideal para cadastros |
#
# ### Exemplo
#
# **Lista**
#
# ```python
# aluno = ["Ana", 20, "Blumenau"]
# ```
#
# Difícil saber o que cada posição representa.
#
# **Dicionário**
#
# ```python
# aluno = {
#     "nome": "Ana",
#     "idade": 20,
#     "cidade": "Blumenau"
# }
# ```
#
# Mais organizado e legível.
#
# ---
#
# # Resumo
#
# | Operação             | Comando                            |
# | -------------------- | ---------------------------------- |
# | Criar                | `{}`                               |
# | Acessar valor        | `dicionario["chave"]`              |
# | Acessar seguro       | `get()`                            |
# | Adicionar            | `dicionario["nova_chave"] = valor` |
# | Alterar              | `dicionario["chave"] = novo_valor` |
# | Remover              | `del` ou `pop()`                   |
# | Chaves               | `keys()`                           |
# | Valores              | `values()`                         |
# | Chaves e valores     | `items()`                          |
# | Verificar existência | `in`                               |
#
# ### Quando usar Dicionários?
#
# ✅ Cadastros de alunos
#
# ✅ Produtos
#
# ✅ Usuários de sistemas
#
# ✅ Configurações de aplicações
#
# ✅ Dados vindos de APIs (JSON)
#
# ✅ Informações organizadas por atributos (nome, idade, cidade, etc.)

# %%
aluno = {
    "nome": "Alexandre",
    "idade": 17,
    "cidade": "Blumenau"
}

print(aluno)
# Out:
# {'nome': 'Alexandre', 'idade': 17, 'cidade': 'Blumenau'}

# %%
aluno = {
    "nome": "Alexandre",
    "idade": 17,
    "cidade": "Blumenau"
}

aluno["idade"] = 20
print(aluno)
# Out:
# {'nome': 'Alexandre', 'idade': 20, 'cidade': 'Blumenau'}

# %%
aluno = {
    "nome": "Alexandre",
    "idade": 20,
    "cidade": "Blumenau"
}

aluno["profissão"] = "Programador Python"
print(aluno)
# Out:
# {'nome': 'Alexandre', 'idade': 20, 'cidade': 'Blumenau', 'profissão': 'Programador Python'}

# %%
aluno = {
    "nome": "Alexandre",
    "idade": 20,
    "cidade": "Blumenau",
    "profissão": "Programador Python",
}

# percorrer o dicionário
for chave, valor in aluno.items():
    print(f"{chave}: {valor}")
# Out:
# nome: Alexandre
# idade: 20
# cidade: Blumenau
# profissão: Programador Python

# %%
# Sistema simples de cadastro de produtos:
produto = {
    "nome": "Notebook",
    "preco": 3500,
    "estoque": 10
}
# Exibir todas as informações
for chave, valor in produto.items():
    print(f"{chave}: {valor}")

# %%
# Agenda telefônica com pelo menos 5 contatos
agenda = {
    "Joaquim": "345-3245",
    "Mariana": "3333-66666",
    "Paulo": "7777-88888",
    "Maria": "9999-00000",
    "Ana": "2222-55555",
}

# Permitir ao usuário pesquisar um nome
while True:
    nome = input("Digite um nome da agenda para pesquisar (ou 'sair'): ")

    if nome.lower() == "sair":
        print("Encerrando a agenda.")
        break

    if nome in agenda:
        print(f"O telefone de {nome} é {agenda[nome]}")
    else:
        print("O nome digitado não está na agenda.")

# %%
# criar uma lista de dicionário contendo 3 alunos

alunos = [
    {"nome": "João", "idade": 18, "cidade": "Blumenau"},
    {"nome": "Maria", "idade": 19, "cidade": "Florianópolis"},
    {"nome": "Pedro", "idade": 20, "cidade": "Joinville"},
]

# Exibir todos os dados usando laço for
for aluno in alunos:
    for chave, valor in aluno.items():
        print(f"{chave}: {valor}")
# Out:
# nome: João
# idade: 18
# cidade: Blumenau
# nome: Maria
# idade: 19
# cidade: Florianópolis
# nome: Pedro
# idade: 20
# cidade: Joinville
